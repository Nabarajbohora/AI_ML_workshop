# %%
import pandas as pd
data = {
    "student_name": ['Nabaraj', 'Bob', "Charlie", 'Diana', "Nabaraj"],
    "hours_studies": [5,8,5,10,5,],
    "previous_score": [65, 85, 55, 92,65],
    "attendance": [80, 90, 70, 95,80],
    "sleep_hours": [7.5,8.0,6.0,9.0,7.5],
    "extracurricular": ["Yes","No", "Yes", "Yes", "yes"],
    "parent_education": ["Bachelor", "bachelor", "High Scholl", "PHD", "Bachelor"]
}
df= pd.DataFrame(data)
print(df)
print("student info")
print (df.info())
print()
#View Data 
print( "Fisrt 5 rows:")
print(df.head(3))
# Out:
#   student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 0        Alice              5              65          80          7.5
# 1          Bob              8              85          90          8.0
# 2      Charlie              3              55          70          6.0
# 3        Diana             10              92          95          9.0
# 4          Eva              6              75          85          7.0
#
#   extracurricular parent_education
# 0             Yes         Bachelor
# 1              No           Master
# 2             Yes      High Scholl
# 3             Yes              PHD
# 4              No         Bachelor
# student info
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_name      5 non-null      str
#  1   hours_studies     5 non-null      int64
# ...

# %%
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# student_name        0
# hours_studies       0
# previous_score      0
# attendance          0
# sleep_hours         0
# extracurricular     0
# parent_education    0
# dtype: int64

# %%
#check duplicate
print ("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %%
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# student_name        0
# hours_studies       0
# previous_score      0
# attendance          0
# sleep_hours         0
# extracurricular     0
# parent_education    0
# dtype: int64

# %%
print("\nMissing values:")
print(df.isnull().sum)
# Out:
# Missing values:
# <bound method DataFrame.sum of    student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 0         False          False           False       False        False
# 1         False          False           False       False        False
# 2         False          False           False       False        False
# 3         False          False           False       False        False
# 4         False          False           False       False        False
#
#    extracurricular  parent_education
# 0            False             False
# 1            False             False
# 2            False             False
# 3            False             False
# 4            False             False  >

# %%
print(df.head(3))
# Out:
#   student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 0        Alice              5              65          80          7.5
# 1          Bob              8              85          90          8.0
# 2      Charlie              3              55          70          6.0
#
#   extracurricular parent_education
# 0             Yes         Bachelor
# 1              No           Master
# 2             Yes      High Scholl

# %%
print(df.tail(2))
# Out:
#   student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 3        Diana             10              92          95          9.0
# 4          Eva              6              75          85          7.0
#
#   extracurricular parent_education
# 3             Yes              PHD
# 4              No         Bachelor

# %%
print("\nMissing values:")
print(df.isnull().subtract)
# Out:
# Missing values:
# <bound method DataFrame.sub of    student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 0         False          False           False       False        False
# 1         False          False           False       False        False
# 2         False          False           False       False        False
# 3         False          False           False       False        False
# 4         False          False           False       False        False
#
#    extracurricular  parent_education
# 0            False             False
# 1            False             False
# 2            False             False
# 3            False             False
# 4            False             False  >

# %%
print("\nMissing values:")
print(df.isnull().sum)
# Out:
# Missing values:
# <bound method DataFrame.sum of    student_name  hours_studies  previous_score  attendance  sleep_hours  \
# 0         False          False           False       False        False
# 1         False          False           False       False        False
# 2         False          False           False       False        False
# 3         False          False           False       False        False
# 4         False          False           False       False        False
#
#    extracurricular  parent_education
# 0            False             False
# 1            False             False
# 2            False             False
# 3            False             False
# 4            False             False  >
